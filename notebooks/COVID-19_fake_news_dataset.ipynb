# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-packages" data-toc-modified-id="Load-packages-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load packages</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Webscraping" data-toc-modified-id="Webscraping-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Webscraping</a></span><ul class="toc-item"><li><span><a href="#Extract-info-of-each-hyperlink-to-build-dataset" data-toc-modified-id="Extract-info-of-each-hyperlink-to-build-dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Extract info of each hyperlink to build dataset</a></span></li></ul></li><li><span><a href="#Some-EDA" data-toc-modified-id="Some-EDA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Some EDA</a></span><ul class="toc-item"><li><span><a href="#Unique-fact_checkers" data-toc-modified-id="Unique-fact_checkers-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Unique fact_checkers</a></span></li><li><span><a href="#Trying-to-eliminate-NaN" data-toc-modified-id="Trying-to-eliminate-NaN-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Trying to eliminate NaN</a></span><ul class="toc-item"><li><span><a href="#Saving-cleaned-data" data-toc-modified-id="Saving-cleaned-data-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Saving cleaned data</a></span></li></ul></li><li><span><a href="#Period-covered-by-our-dataset" data-toc-modified-id="Period-covered-by-our-dataset-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Period covered by our dataset</a></span></li><li><span><a href="#Labels" data-toc-modified-id="Labels-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Labels</a></span></li></ul></li></ul></div>

# %% [markdown]
# In this notebook we scrap https://www.poynter.org/ifcn-covid-19-misinformation/ in order to obtain data about fake news concerning COVID-19 from different fact checkers.

# %% [markdown]
# # Load packages

# %%
# importing packages

import requests
# from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import time
import pickle
from tqdm import tqdm
import pandas as pd
import numpy as np

TodaysDate = time.strftime("%Y-%m-%d")

# Set max rows displayed in output to 4000
pd.set_option("display.max_rows", 4000)

# %% [markdown]
# # Functions

# %%
def retrieve_news_hyperlinks(main_url):
    """ 
    Extract all hyperlinks in 'main_url' and return a list with these hyperlinks 
    """
    
    # Packages the request, send the request and catch the response: r
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
    
    # Packages the request, send the request and catch the response: r
    
    r = requests.get(main_url, headers=headers)
    
    # Create a BeautifulSoup object from the HTML: soup
    
    soup = BeautifulSoup(r.text,"lxml")
    
    # Find all 'a' tags (which define hyperlinks): a_tags

    a_tags = soup.find_all('a')

    # Create a list with hyperlinks found

    list_links = [link.get('href') for link in a_tags]
    
    # keep only news links (i.e. containing "?ifcn_misinformation")
    
    list_news = [link for link in list_links if "?ifcn_misinformation" in link]
    
    # remove duplicates
    
    list_news = list(set(list_news))
    
    # Remove none values if there is some
    
    list_news = list(filter(None, list_news)) 
    
    return list_news

# %%
def save_list(list_to_save, pickle_path):
    """ 
    Save list using pickle
    
    Input:
        list_to_save: list that will be saved
        pickle_name: name that the pickle file will receive without .pkl extension
    """
    
    with open(pickle_path+'_'+TodaysDate+'.pkl', 'wb') as f:
        pickle.dump(list_to_save, f)
        
    print(pickle_path+'_'+TodaysDate+'.pkl')
        
    return pickle_path+'_'+TodaysDate+'.pkl'
    
def load_list(list_path):
    """ 
    Load list saved as pickle file
    """
    
    with open(list_path, 'rb') as f:
        newlist = pickle.load(f)
        
    return newlist

# %%
def build_csv(list_news_urls):
    """ 
    Build csv with extract information of hyperlinks in list of hyperlinks of Poynter.
    
    """
    
    #list of information extract from website
    
    fact_checker = []
    date = []
    location = []
    label = []
    title = []
    explanation = []
    claim_originated_by = []
    url_checker = []
    
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
        
    for idx in tqdm(range(len(list_news_urls))):
        
        r = requests.get(list_news_urls[idx], headers=headers)
    
        # Create a BeautifulSoup object from the HTML: soup
        soup = BeautifulSoup(r.text,"lxml")

        fact_checker.append(soup.find('p', class_='entry-content__text entry-content__text--org').get_text().split(':')[-1].strip())

        date_location = soup.find('p', class_="entry-content__text entry-content__text--topinfo").get_text()
    
        date.append(date_location.split('|')[-2])

        location.append(date_location.split('|')[-1].strip())

        label_title = soup.find("h1",class_="entry-title").get_text()

        label.append(label_title.split(":")[0].replace("\n","").strip().lower())

        title.append(label_title.split(":")[1].replace("\t\t","").strip())

        explanation.append(soup.find('p',class_="entry-content__text entry-content__text--explanation").get_text().split(":")[1].strip())

        claim_originated_by.append(soup.find('p', class_="entry-content__text entry-content__text--smaller").get_text().split(":")[1].strip())

        url_checker.append(soup.find('a', class_="button entry-content__button entry-content__button--smaller").get("href"))

    dict_info = {'fact_checker':fact_checker,
                 'date':date, 
                 'location': location,
                 'label':label,
                 'title':title,
                 'explanation':explanation,
                 'claim_originated_by':claim_originated_by,
                 'url_checker':url_checker}
    
    df = pd.DataFrame(dict_info)

    return df

# %% [markdown]
# # Webscraping

# %%
main_url = "https://www.poynter.org/ifcn-covid-19-misinformation/?orderby=views&order=DESC"

# %%
# list of hyperlinks in the 1st page

list_news = retrieve_news_hyperlinks(main_url)

list_news
# Out:
# ['https://www.poynter.org/?ifcn_misinformation=facebook-posts-shared-in-at-least-three-countries-as-scientists-work-to-develop-a-covid-19-vaccine-claim-to-offer-a-legal-way-to-refuse-vaccination',
#  'https://www.poynter.org/?ifcn_misinformation=a-video-shows-an-empty-hospital-it-states-that-although-globo-said-there-were-already-7-patients-at-a-temporary-covid-19-hospital-built-in-fortaleza-brazil-the-video-proves-it-is-still-not-working',
#  'https://www.poynter.org/?ifcn_misinformation=clinical-trials-with-chlorine-dioxide-cds-allegedly-initiated-by-the-american-institute-of-health',
#  'https://www.poynter.org/?ifcn_misinformation=the-canadian-federal-governement-gives-756-to-every-citizen',
#  'https://www.poynter.org/?ifcn_misinformation=colombia-is-the-country-with-less-cases-and-deaths-for-coronavirus-per-inhabitant-in-america',
#  'https://www.poynter.org/?ifcn_misinformation=video-of-an-fbi-raid-in-the-captions-it-says-the-agents-were-seizing-chinese-n95-masks-that-were-contaminated-with-covid-19',
#  'https://www.poynter.org/?ifcn_misinformation=you-should-wear-the-colored-side-of-the-mask-on-the-outside-when-you-are-sick-and-the-white-side-on-the-outside-when-you-are-healthy',
#  'https://www.poynter.org/?ifcn_misinformation=typing-21-on-your-cell-phone-lets-you-know-if-youre-being-spied-on-because-of-covid-19-geolocation-measures-in-quebec',
#  'https://www.poynter.org/?ifcn_misinformation=photographs-of-killer-whales-allegedly-taken-in-el-medano-tenerife-during-confinement-by-the-coronavirus',
#  'https://www.poynter.org/?ifcn_misinformation=criminals-give-contaminated-masks-from-door-to-door-to-make-people-fall-asleep-and-rob-them',
#  'https://www.poynter.org/?ifcn_misinformation=coronavirus-was-created-in-a-lab-in-china',
#  'https://www.poynter.org/?ifcn_misinformation=being-behind-a-jogger-or-a-cyclist-makes-you-at-risk-of-contracting-covid-19',
#  'https://www.poynter.org/?ifcn_misinformation=coronavirus-was-created-in-a-lab-in-china-in-2013',
#  'https://www.poynter.org/?ifcn_misinformation=coronavirus-was-created-from-hiv',
#  'https://www.poynter.org/?ifcn_misinformation=mix-of-jambu-lemon-and-garlic-does-not-heal-covid-19']

# %%
# retrieve all hyperlinks from all 308 pages with corona news 

all_news_links = retrieve_news_hyperlinks(main_url)

for page in tqdm(range(309)):
    if page == 0:
        all_news_links = retrieve_news_hyperlinks(main_url)
    else:     
        all_news_links.extend(retrieve_news_hyperlinks("https://www.poynter.org/ifcn-covid-19-misinformation/page/"+str(page)+"/?orderby=views&order=DESC#038;order=DESC"))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 309/309 [04:04<00:00,  1.27it/s]

# %%
len(all_news_links)
# Out:
# 4623

# %%
# save list of hyperlinks in a pickle file

save_list(all_news_links, "../data/all_news_links")
# Out:
# ../data/all_news_links_2020-04-24.pkl
# '../data/all_news_links_2020-04-24.pkl'

# %%
# load this list to check if everything is fine

list_test = load_list("../data/all_news_links_2020-04-24.pkl")

# %%
# comparing to check if it was saved properly

all_news_links == list_test
# Out:
# True

# %% [markdown]
# ## Extract info of each hyperlink to build dataset
#
# Retrieving all data at once cause a connection problem so it was necessary to do it in pieces.

# %%
df1 = build_csv(list_test[:1000])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [18:13<00:00,  1.09s/it]

# %%
df1.head()
# Out:
#                  fact_checker         date                          location  \
# 0                         AFP  2020/04/22   United States, Canada, Australia
# 1                Agência Lupa  2020/04/22                             Brazil
# 2                  Maldita.es  2020/04/22                    Spain, Colombia
# 3  Décrypteurs - Radio-Canada  2020/04/23                             Canada
# 4              La Silla Vacía  2020/04/22                           Colombia
#
#         label                                              title  \
# 0       false  Facebook posts shared in at least three countr...
# 1       false  A video shows an empty hospital. It states tha...
# 2  misleading  Clinical trials with chlorine dioxide (CDS) al...
# 3       false  The Canadian federal governement gives 756 $ t...
# 4       false  Colombia is the country with less cases and de...
#
#                                          explanation claim_originated_by  \
# 0  The claims are false; immunization is not comp...                  FB
# 1  This video was originally published on April 1...      Facebook posts
# 2  The study will not be carried out by the Natio...            WhatsApp
# 3  The link to sign up for this program leads to ...            Facebook
# 4  Colombia is the third country with less cases ...            Facebook
#
#                                          url_checker
# 0  https://factcheck.afp.com/false-advice-refusin...
# 1  https://piaui.folha.uol.com.br/lupa/2020/04/22...
# 2  https://maldita.es/malditaciencia/2020/04/22/q...
# 3  https://ici.radio-canada.ca/nouvelle/1694856/i...
# 4  https://lasillavacia.com/detector-no-colombia-...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         1000 non-null   object
#  1   date                 1000 non-null   object
#  2   location             1000 non-null   object
#  3   label                1000 non-null   object
#  4   title                1000 non-null   object
#  5   explanation          1000 non-null   object
#  6   claim_originated_by  1000 non-null   object
#  7   url_checker          1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df1.to_csv("../data/data_poynter_part1_"+TodaysDate+".csv", index=False)

# %%
df2 = build_csv(list_test[1000:2000])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [30:28<00:00,  1.83s/it]

# %%
df2.head()
# Out:
#   fact_checker         date       location  label  \
# 0    PesaCheck  2020/04/04   Uganda, Kenya  false
# 1          AFP  2020/04/04           India  false
# 2       Factly  2020/04/04           India  false
# 3          AFP  2020/04/04     West Africa  false
# 4   Maldita.es  2020/04/04           Spain  false
#
#                                                title  \
# 0  Uganda has postponed general elections due to ...
# 1  A video has been viewed thousands of times on ...
# 2  Video of Rahul Gandhi and Priyanka Vadra Gandh...
# 3  An hospital was set on fire in Nairobi after p...
# 4  The Spanish political party Vox assures that t...
#
#                                          explanation claim_originated_by  \
# 0  There has not been such a directive from Presi...             Website
# 1  The claim is false; the video was published on...                  FB
# 2  The video is three months old. In December 201...        Social Media
# 3  To this day, there is still no vaccine against...        Social media
# 4  The government is not hiding the images of cof...             Twitter
#
#                                          url_checker
# 0  https://pesacheck.org/hoax-ugandas-2021-genera...
# 1  https://factcheck.afp.com/video-predates-india...
# 2  https://factly.in/an-old-video-falsely-shared-...
# 3  https://factuel.afp.com/non-aucun-hopital-na-e...
# 4  https://maldita.es/malditobulo/2020/04/04/no-e...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         1000 non-null   object
#  1   date                 1000 non-null   object
#  2   location             1000 non-null   object
#  3   label                1000 non-null   object
#  4   title                1000 non-null   object
#  5   explanation          1000 non-null   object
#  6   claim_originated_by  1000 non-null   object
#  7   url_checker          1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
# save df in csv

df2.to_csv("../data/data_poynter_part2_"+TodaysDate+".csv", index=False)

# %%
df3 = build_csv(list_test[2000:3000])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [36:23<00:00,  2.18s/it]

# %%
df3.head()
# Out:
#   fact_checker         date                location  label  \
# 0   franceinfo  2020/03/24                   France  false
# 1      Rappler  2020/03/24              Philippines  false
# 2    La Nación  2020/03/24               Costa Rica  false
# 3          AFP  2020/03/24   Sri Lanka, Philippines  false
# 4    PesaCheck  2020/03/24                    Kenya  false
#
#                                                title  \
# 0  This photo shows nurses insulting French Presi...
# 1  Globe Telecom is giving every subscriber free ...
# 2  In Costa Rica, dead bodies are not returned to...
# 3  Purported advisories urging residents to stay ...
# 4        23 new COVID-19 cases confirmed in Mombasa.
#
#                                          explanation claim_originated_by  \
# 0  The image has been modified. The original phot...             Twitter
# 1  In a message sent to Rappler, Globe said the f...             Website
# 2  There are procedures in place, and the bodies ...  Facebook, WhatsApp
# 3  The claim is false. Both the Sri Lankan and Ph...  Facebook, WhatsApp
# 4  The cases were not confirmed by Kenya's Minist...    Times Live Kenya
#
#                                          url_checker
# 0  https://www.francetvinfo.fr/sante/maladie/coro...
# 1  https://www.rappler.com/newsbreak/fact-check/2...
# 2  https://www.nacion.com/no-coma-cuento/nocomacu...
# 3  https://factcheck.afp.com/false-claim-circulat...
# 4  https://pesacheck.org/false-kenya-has-not-conf...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         1000 non-null   object
#  1   date                 1000 non-null   object
#  2   location             1000 non-null   object
#  3   label                1000 non-null   object
#  4   title                1000 non-null   object
#  5   explanation          1000 non-null   object
#  6   claim_originated_by  1000 non-null   object
#  7   url_checker          1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df3.to_csv("../data/data_poynter_part3_"+TodaysDate+".csv", index=False)

# %%
df4 = build_csv(list_test[3000:4000])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [36:23<00:00,  2.18s/it]

# %%
df4.head()
# Out:
#               fact_checker         date            location  label  \
# 0                Faktograf  2020/03/15              Croatia  false
# 1  Taiwan FactCheck Center  2020/03/15               Taiwan  false
# 2                PesaCheck  2020/03/15   Kenya, East Africa  false
# 3            Agencia Ocote  2020/03/15            Guatemala  false
# 4                PesaCheck  2020/03/15   Kenya, East Africa  false
#
#                                                title  \
# 0             COVID-19 arrived in the U.S. by train.
# 1  COVID-19 is large in size, where the cell diam...
# 2  Graphics with information about COVID-19 conta...
# 3  Helicopter of the armed forces disinfects the ...
# 4  A situation update allegedly from Kenya’s Citi...
#
#                                          explanation  \
# 0                    The photo has been manipulated.
# 1  The cell diameter is around 120 nanometers. Th...
# 2  A series of infographics with UNICEF branding ...
# 3                               This claim is false.
# 4  A post about COVID-19 in Kenya that contains a...
#
#               claim_originated_by  \
# 0                        Facebook
# 1                  Line, Facebook
# 2  Kenya Broadcasting Corporation
# 3                 Social networks
# 4                           Tweet
#
#                                          url_checker
# 0  https://faktograf.hr/2020/03/16/vagon-vlak-cov...
# 1            https://tfc-taiwan.org.tw/articles/3382
# 2  https://pesacheck.org/fake-these-infographics-...
# 3  https://agenciaocote.com/bulo-ningun-helicopte...
# 4  https://pesacheck.org/hoax-this-post-with-a-si...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         1000 non-null   object
#  1   date                 1000 non-null   object
#  2   location             1000 non-null   object
#  3   label                1000 non-null   object
#  4   title                1000 non-null   object
#  5   explanation          1000 non-null   object
#  6   claim_originated_by  1000 non-null   object
#  7   url_checker          1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df4.to_csv("../data/data_poynter_part4_"+TodaysDate+".csv", index=False)

# %%
df5 = build_csv(list_test[4000:])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 623/623 [22:09<00:00,  2.13s/it]

# %%
df5.head()
# Out:
#     fact_checker         date     location       label  \
# 0     Maldita.es  2020/02/13         Spain       false
# 1            AFP  2020/02/13   Philippines       false
# 2  Efecto Cocuyo  2020/02/13     Venezuela       false
# 3      The Quint  2020/02/14         India  misleading
# 4   Vishvas News  2020/02/13         India       false
#
#                                                title  \
# 0                     Claims of cannibalism in China
# 1                    Boiled ginger can cure COVID-19
# 2  There is a Cuban drug used in China against th...
# 3         Coronavirus was created in a lab in Wuhan.
# 4                        Weed kills the coronavirus.
#
#                                          explanation  \
# 0              The image shows an autopsy on a baby.
# 1                           Doctors deny this claim.
# 2  Story cites the president and the Cuban embass...
# 3  No scientific evidence supports that the coron...
# 4                Weed does not kill the coronavirus.
#
#                    claim_originated_by  \
# 0                            Instagram
# 1                 Katja Helena Ristilä
# 2  Miguel Díaz-Canel, Cuba´s president
# 3                              Twitter
# 4                              Twitter
#
#                                          url_checker
# 0  https://maldita.es/malditobulo/bulo-personas-a...
# 1                     http://u.afp.com/GingerCovid19
# 2  https://efectococuyo.com/cocuyo-chequea/medica...
# 3  https://fit.thequint.com/fit-webqoof/fit-webqo...
# 4  https://www.vishvasnews.com/english/health/fac...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         623 non-null    object
#  1   date                 623 non-null    object
#  2   location             623 non-null    object
#  3   label                623 non-null    object
#  4   title                623 non-null    object
#  5   explanation          623 non-null    object
#  6   claim_originated_by  623 non-null    object
#  7   url_checker          623 non-null    object
# dtypes: object(8)
# memory usage: 39.1+ KB

# %%
df5.to_csv("../data/data_poynter_part5_"+TodaysDate+".csv", index=False)

# %%
# concatenate all data
df_concat = pd.concat([df1,df2,df3,df4,df5])

# drop duplicates if there is
df_concat.drop_duplicates(subset=['date','location','title'], keep='first', inplace = True)

# reset index
df_concat.reset_index(drop=True,inplace = True)

# save in csv
df_concat.to_csv("../data/data_poynter_COMPLETE_"+TodaysDate+".csv", index=False)

#save in excel
df_concat.to_excel("../data/data_poynter_COMPLETE_"+TodaysDate+".xlsx")

# %% [markdown]
# Apparently, there where some duplicates based on `date`, `location`, and `title`. This reduced the expected data of 4623 to 3934.

# %%
df_conc_temp = pd.read_csv("../data/data_poynter_COMPLETE_"+TodaysDate+".csv")

# %%
df_conc_temp.head()
# Out:
#                  fact_checker         date                          location  \
# 0                         AFP  2020/04/22   United States, Canada, Australia
# 1                Agência Lupa  2020/04/22                             Brazil
# 2                  Maldita.es  2020/04/22                    Spain, Colombia
# 3  Décrypteurs - Radio-Canada  2020/04/23                             Canada
# 4              La Silla Vacía  2020/04/22                           Colombia
#
#         label                                              title  \
# 0       false  Facebook posts shared in at least three countr...
# 1       false  A video shows an empty hospital. It states tha...
# 2  misleading  Clinical trials with chlorine dioxide (CDS) al...
# 3       false  The Canadian federal governement gives 756 $ t...
# 4       false  Colombia is the country with less cases and de...
#
#                                          explanation claim_originated_by  \
# 0  The claims are false; immunization is not comp...                  FB
# 1  This video was originally published on April 1...      Facebook posts
# 2  The study will not be carried out by the Natio...            WhatsApp
# 3  The link to sign up for this program leads to ...            Facebook
# 4  Colombia is the third country with less cases ...            Facebook
#
#                                          url_checker
# 0  https://factcheck.afp.com/false-advice-refusin...
# 1  https://piaui.folha.uol.com.br/lupa/2020/04/22...
# 2  https://maldita.es/malditaciencia/2020/04/22/q...
# 3  https://ici.radio-canada.ca/nouvelle/1694856/i...
# 4  https://lasillavacia.com/detector-no-colombia-...

# %%
df_conc_temp.tail()
# Out:
#           fact_checker         date        location            label  \
# 3929  Science Feedback  2020/01/22   United Kingdom      no evidence
# 3930  Pagella Politica  2020/01/22            Italy            false
# 3931   Animal Político  2020/01/18           Mexico            false
# 3932           Rappler  2020/01/14      Philippines            false
# 3933   Animal Político  2020/01/19           Mexico  partially false
#
#                                                   title  \
# 3929  The new coronavirus outbreak is linked to eati...
# 3930                                            Warning
# 3931  Stores and supermarkets in Veracruz (Mexico) w...
# 3932  A chain message circulated on Tuesday, Jan. 14...
# 3933  The peak of the new coronavirus will happen in...
#
#                                             explanation  \
# 3929  Bats are known natural reservoirs for coronavi...
# 3930  Until Jan. 22, this information hadn't been co...
# 3931  As of Mar. 18, stores had not said they woud c...
# 3932  The Department of Health (DOH) and Healthway M...
# 3933  Authorities say that what lasts two weeks or l...
#
#                                     claim_originated_by  \
# 3929  Emma Parker, writer at the Daily Star (and man...
# 3930                                      retenews24.it
# 3931                                           WhatsApp
# 3932                                      Chain message
# 3933                                           WhatsApp
#
#                                             url_checker
# 3929  https://healthfeedback.org/claimreview/no-conc...
# 3930  https://pagellapolitica.it/bufale/show/902/not...
# 3931  https://www.animalpolitico.com/elsabueso/falso...
# 3932  https://www.rappler.com/newsbreak/fact-check/2...
# 3933  https://www.animalpolitico.com/elsabueso/caden...

# %%
df_conc_temp.shape
# Out:
# (3934, 8)

# %% [markdown]
# # Some EDA

# %%
df_conc_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         3933 non-null   object
#  1   date                 3934 non-null   object
#  2   location             3934 non-null   object
#  3   label                3934 non-null   object
#  4   title                3934 non-null   object
#  5   explanation          3932 non-null   object
#  6   claim_originated_by  3866 non-null   object
#  7   url_checker          3933 non-null   object
# dtypes: object(8)
# memory usage: 246.0+ KB

# %% [markdown]
# ## Unique fact_checkers

# %%
# there were a float in the middle of the fact_checker, probably the `nan`

df_conc_temp.fact_checker = df_conc_temp.fact_checker.apply(lambda x: str(x))

# %%
list_fact_checkers = df_conc_temp.fact_checker.unique().tolist()
list_fact_checkers.sort()
list_fact_checkers
# Out:
# ['15min.lt',
#  'AAP FactCheck',
#  'AFP',
#  'AfricaCheck',
#  'Agencia Ocote',
#  'Agência Lupa',
#  'Animal Político',
#  'Annie Lab',
#  'Aos Fatos',
#  'BOOM FactCheck',
#  'Bolivia Verifica',
#  'BuzzFeed Japan',
#  'Check',
#  'Check Your Fact',
#  'CheckNews',
#  'Chequeado',
#  'Colombiacheck',
#  'Convoca.pe',
#  'Correctiv',
#  'Delfi Melo Detektorius (Lie Detector)',
#  'Demagog',
#  'Dubawa',
#  'Décrypteurs - Radio-Canada',
#  'Décrypteurs - Radio-Canada and CBC',
#  'Détecteur de rumeurs',
#  'EFE Verifica',
#  'Ecuador Chequea',
#  'Efecto Cocuyo',
#  'Effecinque - SkyTg24',
#  'El Surtidor',
#  'Ellinika Hoaxes',
#  'Estadão Verifica',
#  'FactCheck Georgia',
#  'FactCheck.org',
#  'FactCrescendo',
#  'Factcheck.Vlaanderen',
#  'Factcheck.kz',
#  'Factly',
#  'Factnameh',
#  'Faktabaari/FactBar',
#  'Faktograf',
#  'Fatabyyano',
#  'France 24 Observers',
#  'Full Fact',
#  'GhanaFact',
#  'INFACT',
#  'India Today',
#  'Istinomer',
#  'JTBC news',
#  'La Nación',
#  'La Silla Vacía',
#  'La Voz de Guanacaste',
#  'LeadStories',
#  'Les Décodeurs',
#  'Maldita.es',
#  'MediaWise',
#  'Misbar',
#  'Myth Detector',
#  'NewsMobile',
#  'Newschecker',
#  'Newtral.es',
#  'Nieuwscheckers',
#  'Observador',
#  'OjoPúblico',
#  'Open',
#  'Pagella Politica',
#  'Periodismo de Barrio',
#  'PesaCheck',
#  'Poligrafo',
#  'PolitiFact',
#  'Rappler',
#  'Raskrinkavanje',
#  'Salud con lupa',
#  'Science Feedback',
#  'Spondeo Media',
#  'Sure And Share Center MCOT',
#  'TEMPO',
#  'Taiwan FactCheck Center',
#  'Teyit',
#  'The Quint',
#  'TheJournal.ie',
#  'TjekDet.dk',
#  'VERA Files',
#  'Verificado',
#  'Vishvas News',
#  'Vistinomer',
#  'VoxCheck',
#  'Washington Post Fact-Checker',
#  'franceinfo',
#  'nan']

# %%
len(list_fact_checkers)
# Out:
# 90

# %% [markdown]
# ## Trying to eliminate NaN

# %% [markdown]
# There is one news without checker. This one should be eliminated from the dataset?

# %%
df_conc_temp[df_conc_temp.fact_checker=='nan']
# Out:
#      fact_checker         date       location  label  \
# 1236          nan  2020/03/26   Spain, Russia  false
#
#                                                   title  \
# 1236  Putin accuses US and EU leaders of artificiall...
#
#                                             explanation  \
# 1236  This is the video of a speech by the Russian l...
#
#                        claim_originated_by  \
# 1236  Video posted on Facebook and Youtube
#
#                                             url_checker
# 1236  https://www.efe.com/efe/espana/efeverifica/put...

# %%
df_conc_temp.title[df_conc_temp.fact_checker=='nan'].values[0]
# Out:
# 'Putin accuses US and EU leaders of artificially creating COVID-19 to reduce world population.'

# %%
df_conc_temp.url_checker[df_conc_temp.fact_checker=='nan'].values[0]
# Out:
# 'https://www.efe.com/efe/espana/efeverifica/putin-no-acusa-a-la-ue-ni-eeuu-de-crear-el-coronavirus/50001435-4205887'

# %%
df_conc_temp.fact_checker[df_conc_temp.url_checker.str.contains('efe.com', na=True)]
# Out:
# 1236              nan
# 1354     EFE Verifica
# 1387     EFE Verifica
# 1390     EFE Verifica
# 1490     EFE Verifica
# 1636    Les Décodeurs
# 1807     EFE Verifica
# 1811     EFE Verifica
# 2068     EFE Verifica
# 2070     EFE Verifica
# 2072     EFE Verifica
# 2174     EFE Verifica
# 2182     EFE Verifica
# 2289     EFE Verifica
# 2292     EFE Verifica
# 2300     EFE Verifica
# 2591     EFE Verifica
# 2638     EFE Verifica
# 2642     EFE Verifica
# 3054     EFE Verifica
# Name: fact_checker, dtype: object

# %% [markdown]
# Therefore, the fact checker here is `EFE Verifica`. We update our dataset.

# %%
df_conc_temp.fact_checker.iloc[1236] = 'EFE Verifica'

# %%
df_conc_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fact_checker         3934 non-null   object
#  1   date                 3934 non-null   object
#  2   location             3934 non-null   object
#  3   label                3934 non-null   object
#  4   title                3934 non-null   object
#  5   explanation          3932 non-null   object
#  6   claim_originated_by  3866 non-null   object
#  7   url_checker          3933 non-null   object
# dtypes: object(8)
# memory usage: 246.0+ KB

# %%
df_conc_temp[df_conc_temp.url_checker.isna()]
# Out:
#        fact_checker         date location         label  \
# 1636  Les Décodeurs  2020/03/22    France  partly false
#
#                                                   title  \
# 1636  Yves Levy, husband of the former french health...
#
#                                             explanation claim_originated_by  \
# 1636  The virus wasn't created in Wuhan's P4 laborat...            Facebook
#
#      url_checker
# 1636         NaN

# %% [markdown]
# For `explanation` and `url_checker` we cannot fill new values.

# %% [markdown]
# ### Saving cleaned data

# %%
df_conc_temp.to_csv("../data/data_poynter_COMPLETE_2020-04-24_CLEANED.csv", index=False)

# %%
df_conc_temp.to_excel("../data/data_poynter_COMPLETE_2020-04-24_CLEANED.xlsx")

# %% [markdown]
# ## Period covered by our dataset
#
# The data collected in April 24 covers period from January 14, 2020 until April 23, 2020.

# %%
(df_conc_temp.date.min(),df_conc_temp.date.max())
# Out:
# ('2020/01/14 ', '2020/04/23 ')

# %% [markdown]
# ## Labels

# %%
df_conc_temp.label.unique()
# Out:
# array(['false', 'misleading', 'partly false', 'no evidence',
#        'pants on fire!', 'four pinocchios', 'mainly false', 'explanatory',
#        'three pinocchios', 'mostly false', 'incorrect', 'fake',
#        'half true', 'mostly true', 'suspicions', 'partly true',
#        'true but', 'two pinocchios', 'partially false', 'inaccurate',
#        'partially correct', 'misleading/false', 'unproven',
#        "(org. doesn't apply rating)", 'in dispute',
#        'false and misleading', 'not legit (false)', 'mixed', 'half truth',
#        'partially true', 'correct', 'unlikely', 'pants on fire',
#        'conspiracy theory', 'misinformation / conspiracy theory',
#        'fake news', 'unverified', 'not true'], dtype=object)

# %%
df_checker_label = df_conc_temp.groupby(["fact_checker", "label"])["location"].count().reset_index()
df_checker_label.drop(columns = ['location'],inplace=True)
df_checker_label
# Out:
#                               fact_checker                               label
# 0                                 15min.lt                   conspiracy theory
# 1                                 15min.lt                               false
# 2                                 15min.lt                          misleading
# 3                                 15min.lt                     partially false
# 4                            AAP FactCheck                               false
# 5                            AAP FactCheck                     partially false
# 6                                      AFP                               false
# 7                                      AFP                          misleading
# 8                                      AFP                        mostly false
# 9                                      AFP                     partially false
# 10                             AfricaCheck                               false
# 11                             AfricaCheck                          misleading
# 12                           Agencia Ocote                         explanatory
# 13                           Agencia Ocote                               false
# 14                           Agencia Ocote                     partially false
# 15                            Agência Lupa                               false
# 16                            Agência Lupa                     partially false
# 17                            Agência Lupa                        partly false
# 18                         Animal Político                               false
# 19                         Animal Político                          misleading
# 20                         Animal Político                     partially false
# 21                               Annie Lab                               false
# 22                               Annie Lab                          misleading
# 23                               Aos Fatos                               false
# 24                               Aos Fatos                     partially false
# 25                          BOOM FactCheck                               false
# 26                          BOOM FactCheck                          misleading
# 27                          BOOM FactCheck                     partially false
# 28                        Bolivia Verifica                               false
# 29                        Bolivia Verifica                          misleading
# 30                          BuzzFeed Japan                               false
# 31                          BuzzFeed Japan                          inaccurate
# 32                          BuzzFeed Japan                          misleading
# 33                          BuzzFeed Japan                        mostly false
# 34                                   Check                               false
# 35                         Check Your Fact                               false
# 36                               CheckNews                               false
# 37                               CheckNews                          misleading
# 38                               CheckNews                        mostly false
# 39                               Chequeado                               false
# 40                               Chequeado                          misleading
# 41                               Chequeado                         no evidence
# 42                           Colombiacheck                               false
# 43                           Colombiacheck                          misleading
# 44                           Colombiacheck                     partially false
# 45                           Colombiacheck                            true but
# 46                              Convoca.pe                               false
# 47                               Correctiv                             correct
# 48                               Correctiv                               false
# 49                               Correctiv                        mainly false
# 50                               Correctiv                        mostly false
# 51                               Correctiv                         mostly true
# 52                               Correctiv                         no evidence
# 53                               Correctiv                     partially false
# 54                               Correctiv                        partly false
# 55   Delfi Melo Detektorius (Lie Detector)                               false
# 56                                 Demagog                               false
# 57                                 Demagog                          misleading
# 58                                 Demagog                     partially false
# 59                                  Dubawa                               false
# 60                                  Dubawa                          misleading
# 61                                  Dubawa                        mostly false
# 62              Décrypteurs - Radio-Canada                               false
# 63              Décrypteurs - Radio-Canada                          misleading
# 64              Décrypteurs - Radio-Canada                        partly false
# 65      Décrypteurs - Radio-Canada and CBC                               false
# 66                    Détecteur de rumeurs                               false
# 67                    Détecteur de rumeurs                     partially false
# 68                            EFE Verifica                               false
# 69                         Ecuador Chequea                               false
# 70                           Efecto Cocuyo                                fake
# 71                           Efecto Cocuyo                               false
# 72                           Efecto Cocuyo                          misleading
# 73                           Efecto Cocuyo                         no evidence
# 74                    Effecinque - SkyTg24                          misleading
# 75                             El Surtidor                               false
# 76                         Ellinika Hoaxes                               false
# 77                         Ellinika Hoaxes  misinformation / conspiracy theory
# 78                        Estadão Verifica                               false
# 79                        Estadão Verifica                     partially false
# 80                        Estadão Verifica                        partly false
# 81                       FactCheck Georgia                           fake news
# 82                       FactCheck Georgia                               false
# 83                           FactCheck.org         (org. doesn't apply rating)
# 84                           FactCheck.org                               false
# 85                           FactCheck.org                          misleading
# 86                           FactCrescendo                               false
# 87                           FactCrescendo                          misleading
# 88                           FactCrescendo                     partially false
# 89                           FactCrescendo                        partly false
# 90                    Factcheck.Vlaanderen                               false
# 91                            Factcheck.kz                               false
# 92                            Factcheck.kz                          misleading
# 93                                  Factly                               false
# 94                                  Factly                          misleading
# 95                                  Factly                         partly true
# 96                               Factnameh                         explanatory
# 97                               Factnameh                               false
# 98                               Factnameh                          misleading
# 99                      Faktabaari/FactBar                          misleading
# 100                              Faktograf                               false
# 101                              Faktograf                          misleading
# 102                             Fatabyyano                               false
# 103                             Fatabyyano                     partially false
# 104                             Fatabyyano                        partly false
# 105                    France 24 Observers                               false
# 106                    France 24 Observers                          misleading
# 107                    France 24 Observers                         no evidence
# 108                    France 24 Observers                          unverified
# 109                              Full Fact                               false
# 110                              GhanaFact                               false
# 111                                 INFACT                               false
# 112                                 INFACT                          misleading
# 113                            India Today                               false
# 114                            India Today                           half true
# 115                            India Today                          misleading
# 116                            India Today                        mostly false
# 117                              Istinomer                               false
# 118                              Istinomer                        mostly false
# 119                              JTBC news                               false
# 120                              JTBC news                          misleading
# 121                              La Nación                               false
# 122                         La Silla Vacía                               false
# 123                         La Silla Vacía                          misleading
# 124                         La Silla Vacía                         no evidence
# 125                         La Silla Vacía                            unproven
# 126                   La Voz de Guanacaste                               false
# 127                            LeadStories                               false
# 128                            LeadStories                          misleading
# 129                            LeadStories                               mixed
# 130                            LeadStories                         no evidence
# 131                            LeadStories                            not true
# 132                            LeadStories                      partially true
# 133                            LeadStories                            unlikely
# 134                          Les Décodeurs                   conspiracy theory
# 135                          Les Décodeurs                         explanatory
# 136                          Les Décodeurs                               false
# 137                          Les Décodeurs                        mainly false
# 138                          Les Décodeurs                          misleading
# 139                          Les Décodeurs                         no evidence
# 140                          Les Décodeurs                     partially false
# 141                          Les Décodeurs                        partly false
# 142                             Maldita.es                         explanatory
# 143                             Maldita.es                               false
# 144                             Maldita.es                          misleading
# 145                             Maldita.es                        mostly false
# 146                             Maldita.es                         no evidence
# 147                             Maldita.es                     partially false
# 148                              MediaWise                               false
# 149                              MediaWise                          misleading
# 150                              MediaWise                         no evidence
# 151                              MediaWise                   not legit (false)
# 152                                 Misbar                               false
# 153                                 Misbar                          misleading
# 154                                 Misbar                          suspicions
# 155                          Myth Detector                   conspiracy theory
# 156                          Myth Detector                               false
# 157                             NewsMobile                               false
# 158                            Newschecker                               false
# 159                            Newschecker                          misleading
# 160                            Newschecker                    misleading/false
# 161                             Newtral.es                         explanatory
# 162                             Newtral.es                               false
# 163                             Newtral.es                          misleading
# 164                             Newtral.es                     partially false
# 165                         Nieuwscheckers                               false
# 166                             Observador                               false
# 167                             OjoPúblico                               false
# 168                             OjoPúblico                          misleading
# 169                                   Open                               false
# 170                       Pagella Politica                                fake
# 171                       Pagella Politica                               false
# 172                       Pagella Politica                          misleading
# 173                   Periodismo de Barrio                               false
# 174                              PesaCheck                               false
# 175                              PesaCheck                          misleading
# 176                              PesaCheck                     partially false
# 177                              Poligrafo                               false
# 178                              Poligrafo                          misleading
# 179                             PolitiFact                               false
# 180                             PolitiFact                           half true
# 181                             PolitiFact                        mostly false
# 182                             PolitiFact                         mostly true
# 183                             PolitiFact                       pants on fire
# 184                             PolitiFact                      pants on fire!
# 185                             PolitiFact                         partly true
# 186                                Rappler                               false
# 187                                Rappler                     partially false
# 188                         Raskrinkavanje                               false
# 189                         Raskrinkavanje                          misleading
# 190                         Salud con lupa                               false
# 191                         Salud con lupa                         no evidence
# 192                       Science Feedback                               false
# 193                       Science Feedback                           incorrect
# 194                       Science Feedback                          misleading
# 195                       Science Feedback                         no evidence
# 196                       Science Feedback                   partially correct
# 197                          Spondeo Media                               false
# 198                          Spondeo Media                          misleading
# 199                          Spondeo Media                         no evidence
# 200                          Spondeo Media                     partially false
# 201             Sure And Share Center MCOT                               false
# 202             Sure And Share Center MCOT                          half truth
# 203                                  TEMPO                               false
# 204                                  TEMPO                          misleading
# 205                                  TEMPO                        partly false
# 206                Taiwan FactCheck Center                         explanatory
# 207                Taiwan FactCheck Center                               false
# 208                Taiwan FactCheck Center                     partially false
# 209                                  Teyit                               false
# 210                                  Teyit                         no evidence
# 211                                  Teyit                     partially false
# 212                                  Teyit                        partly false
# 213                              The Quint                               false
# 214                              The Quint                          misleading
# 215                              The Quint                         partly true
# 216                          TheJournal.ie                               false
# 217                          TheJournal.ie                          misleading
# 218                          TheJournal.ie                        mostly false
# 219                             TjekDet.dk                               false
# 220                             TjekDet.dk                          misleading
# 221                             TjekDet.dk                         no evidence
# 222                             VERA Files                               false
# 223                             VERA Files                          misleading
# 224                             Verificado                               false
# 225                             Verificado                          misleading
# 226                           Vishvas News                                fake
# 227                           Vishvas News                               false
# 228                           Vishvas News                          misleading
# 229                             Vistinomer                               false
# 230                             Vistinomer                false and misleading
# 231                             Vistinomer                          misleading
# 232                             Vistinomer                        mostly false
# 233                             Vistinomer                         no evidence
# 234                               VoxCheck                               false
# 235                               VoxCheck                          misleading
# 236           Washington Post Fact-Checker                               false
# 237           Washington Post Fact-Checker                     four pinocchios
# 238           Washington Post Fact-Checker                          in dispute
# 239           Washington Post Fact-Checker                          misleading
# 240           Washington Post Fact-Checker                    three pinocchios
# 241           Washington Post Fact-Checker                      two pinocchios
# 242                             franceinfo                         explanatory
# 243                             franceinfo                               false
# 244                             franceinfo                          misleading
